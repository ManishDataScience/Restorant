# %% [markdown]
# Description:
# This dataset captures sales transactions from a local restaurant near my home. It includes details such as the order ID, date of the transaction, item names (representing various food and beverage items), item types (categorized as Fast-food or Beverages), item prices, quantities ordered, transaction amounts, transaction types (cash, online, or others), the gender of the staff member who received the order, and the time of the sale (Morning, Evening, Afternoon, Night, Midnight). The dataset offers a valuable snapshot of the restaurant's daily operations and customer behavior.
#
# Columns:
#
# order_id: a unique identifier for each order.
# date: date of the transaction.
# item_name: name of the food.
# item_type: category of item (Fastfood or Beverages).
# item_price: price of the item for 1 quantity.
# Quantity: how much quantity the customer orders.
# transaction_amount: the total amount paid by customers.
# transaction_type: payment method (cash, online, others).
# received_by: gender of the person handling the transaction.
# time_of_sale: different times of the day (Morning, Evening, Afternoon, Night, Midnight).
# Potential Uses:
#
# Analyzing sales trends over time.
# Understanding customer preferences for different items.
# Evaluating the impact of payment methods on revenue.
# Investigating the performance of staff members based on gender.
# Exploring the popularity of items at different times of the day.

# %%
print("By Manish Valmik")
# Out:
# By Manish Valmik

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
m=('Tum Yaar Kitne Osam Ho','Nhi Yaar bas ')
p=('o Yaar ','Kya Yaar')
c='r'
plt.plot(m,p,c)
plt.show()

# %%
res = pd.read_csv('c:\\Users\\Manish ghenght\\Downloads\\archive (4).zip')
res.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
res.shape
# Out:
# (1000, 10)

# %%
res.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
pa=res.fillna(value='Cash')

# %%
pa.isnull().sum()
# Out:
# order_id              0
# date                  0
# item_name             0
# item_type             0
# item_price            0
# quantity              0
# transaction_amount    0
# transaction_type      0
# received_by           0
# time_of_sale          0
# dtype: int64

# %%
pa.head(2)
# Out:
#    order_id        date item_name item_type  item_price  quantity  \
# 0         1  07-03-2022  Aalopuri  Fastfood          20        13
# 1         2   8/23/2022   Vadapav  Fastfood          20        15
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260             Cash         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon

# %%
pa[['item_name','item_price','transaction_type']].head()
# Out:
#          item_name  item_price transaction_type
# 0         Aalopuri          20             Cash
# 1          Vadapav          20             Cash
# 2          Vadapav          20             Cash
# 3  Sugarcane juice          25           Online
# 4  Sugarcane juice          25           Online

# %%
list(pa['item_name'].value_counts()[0:].keys())
# Out:
# ['Cold coffee',
#  'Sugarcane juice',
#  'Panipuri',
#  'Frankie',
#  'Aalopuri',
#  'Vadapav',
#  'Sandwich']

# %%
plt.figure(figsize=(8,5))

plt.bar(list(pa['item_name'].value_counts()[0:].keys()),list(pa['item_name'].value_counts()[0:]),color=["blue","yellow","orange","pink","black","g","cyan"])
plt.xticks(rotation='vertical')
plt.xlabel('Fast food Item Name')

plt.show()

# %%
plt.figure(figsize=(9,9))
plt.pie(list(pa['item_name'].value_counts()),labels=list(pa['item_name'].value_counts().keys()),autopct='%01f%%')
plt.legend(loc=2)
plt.show()

# %%
plt.figure(figsize=(9,9))
plt.pie(list(pa['item_name'].value_counts()),labels=list(pa['item_name'].value_counts().keys()),autopct='%01f%%')
plt.show()

# %%
list(pa['time_of_sale'].value_counts()[0:].keys())
# Out:
# ['Night', 'Afternoon', 'Evening', 'Midnight', 'Morning']

# %%
plt.figure(figsize=(8,4))

plt.bar(list(pa['time_of_sale'].value_counts()[0:].keys()),list(pa['time_of_sale'].value_counts()[0:]),color=["blue","orange","yellow","black","cyan"])
plt.xticks(rotation='vertical')
plt.xlabel('Time of sale Fast food',fontsize=20)

plt.show()

# %%
pa.head(2)
# Out:
#    order_id        date item_name item_type  item_price  quantity  \
# 0         1  07-03-2022  Aalopuri  Fastfood          20        13
# 1         2   8/23/2022   Vadapav  Fastfood          20        15
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260             Cash         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon

# %%
list(pa['item_price'].value_counts()[0:].keys())
# Out:
# [20, 40, 25, 50, 60]

# %%
# sabse jyada kon sa item mehnga hai



plt.bar(pa['item_name'],pa['item_price'],color=["blue","yellow","orange","pink","black","g","cyan"])
plt.xlabel('Item Name',fontsize=15)
plt.ylabel('Price',fontsize=15)

plt.xticks(rotation='vertical')
plt.show()

# %%
list(pa['quantity'].value_counts()[0:].keys())
# Out:
# [13, 10, 7, 15, 14, 1, 2, 6, 5, 12, 3, 8, 9, 4, 11]

# %%
plt.bar(pa['item_name'],pa['quantity'])
plt.xlabel('mamam')
plt.ylabel('pappa')
plt.xticks(rotation='vertical')
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Aalopuri'),
#   Text(1, 0, 'Vadapav'),
#   Text(2, 0, 'Sugarcane juice'),
#   Text(3, 0, 'Panipuri'),
#   Text(4, 0, 'Frankie'),
#   Text(5, 0, 'Sandwich'),
#   Text(6, 0, 'Cold coffee')])

# %%
plt.bar(pa['item_type'],pa['quantity'],color="g")
plt.xlabel('Item Name')
plt.ylabel('Transaction')

plt.xticks(rotation='vertical')
plt.show()

# %%
import seaborn as sns

sns.displot(res["item_price"])
plt.show()

# %%
pa.head(2)
# Out:
#    order_id        date item_name item_type  item_price  quantity  \
# 0         1  07-03-2022  Aalopuri  Fastfood          20        13
# 1         2   8/23/2022   Vadapav  Fastfood          20        15
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260             Cash         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon

# %%
sns.displot(res["quantity"])
sns.displot(res["item_name"])
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.bar(list(pa['item_name'].value_counts()[0:].keys()),list(pa['item_name'].value_counts()[0:]),color=["blue","yellow","orange","pink","black","g","cyan"])
plt.xticks(rotation='vertical')
plt.xlabel('Fast food Item Name')

plt.show()




#...................................#.................................#................................#




plt.bar(pa['item_name'],pa['item_price'],color=["blue","yellow","orange","pink","black","g","cyan"])
plt.xlabel('Item Name',fontsize=15)
plt.ylabel('Price',fontsize=15)

plt.xticks(rotation='vertical')
plt.show()
